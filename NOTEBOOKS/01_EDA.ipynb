# %% [markdown]
# # Phase 1: Exploratory Data Analysis (EDA)
#
# This notebook performs Exploratory Data Analysis on the frozen benchmark datasets (text, labels, metadata) to understand the distribution of PII types, text lengths, and visual annotations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Load benchmark text data
df_text = pd.read_csv('../DATASETS/FINAL_BENCHMARK_DATASET/benchmark_text.csv')
df_text.head()
