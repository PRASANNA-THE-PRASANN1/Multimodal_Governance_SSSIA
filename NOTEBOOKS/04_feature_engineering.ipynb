# %% [markdown]
# # Phase 4: Feature Engineering
#
# This notebook covers feature engineering for our risk and governance layers. We process raw outputs from prompt and vision agents and transform them into tabular features (counts, weights, entity flags).

# %%
import pandas as pd
import numpy as np
