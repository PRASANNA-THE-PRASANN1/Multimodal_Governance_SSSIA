# %% [markdown]
# # Phase 2: Prompt Agent Training & LLM Fine-Tuning
#
# This notebook covers the training / fine-tuning / prompting strategy for the Prompt Agent, including fine-tuning a RoBERTa classifier or prompt template optimization for PII identification.

# %%
import sys
import os
sys.path.append('../AGENTS')
from prompt_agent import PromptAgent
