# %% [markdown]
# # Phase 9: API Demonstration
#
# This notebook demonstrates how to make requests to the FastAPI backend running in `API/app.py` to evaluate text and image files for PII.

# %%
import requests
import json

# %%
# Define base url
BASE_URL = 'http://localhost:8000'

# Check status
resp = requests.get(BASE_URL)
print(resp.json())
