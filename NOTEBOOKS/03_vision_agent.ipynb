# %% [markdown]
# # Phase 3: Vision Agent Development
#
# This notebook focuses on the Vision Agent development, including image loading, visual classification for document types (passports, driver license, signatures), and running OCR tools like Tesseract or EasyOCR.

# %%
import sys
import os
sys.path.append('../AGENTS')
from vision_agent import VisionAgent
